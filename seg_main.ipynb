# %%
import os 

#@title #Get data
#@markdown ## Nhập địa chỉ của thư viện "segment_ai" vào biến **lib_di
#@markdown **Vd: /content/drive/MyDrive/Study/pr_dl/prj_4VNFood/segment_ai**
lib_dir = "/content/drive/MyDrive/Torch_vnfood/utils/segment_ai" #@param {type:"string"}

os.system(f"cp -r {lib_dir} /content/segment_ai")

from segment_ai.get_data import *
path = "/content/segments/hoangsonvothanh_4VNFood/v1"
new_path = "/content/4VNFood" #Doi ten thu muc neu muon
clone_data()
extract2fol(path,new_path)
os.system("rm -rf /content/segments")
#output_type="semantic"
# Out:
# Initializing dataset...
# Preloading all samples. This may take a while...
# ...
#   1%|          | 21/2450 [00:01<02:13, 18.22it/s]WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: segmentsai-prod.s3.eu-west-2.amazonaws.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: segmentsai-prod.s3.eu-west-2.amazonaws.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: segmentsai-prod.s3.eu-west-2.amazonaws.com
# ...
#   7%|▋         | 179/2450 [00:10<01:53, 20.01it/s]WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: segmentsai-prod.s3.eu-west-2.amazonaws.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: segmentsai-prod.s3.eu-west-2.amazonaws.com
# ...
#  13%|█▎        | 320/2450 [00:19<01:27, 24.22it/s]WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: segmentsai-prod.s3.eu-west-2.amazonaws.com
# ...

# %%
# !python seg_main.py
